# %%
import numpy as np
import pandas as pd

houseprice=pd.read_csv('AmesHousing.csv')
houseprice = houseprice.drop("PID", axis=1).drop("Order", axis=1)
houseprice.head()
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0           20        RL         141.0     31770   Pave   NaN       IR1
# 1           20        RH          80.0     11622   Pave   NaN       Reg
# 2           20        RL          81.0     14267   Pave   NaN       IR1
# 3           20        RL          93.0     11160   Pave   NaN       Reg
# 4           60        RL          74.0     13830   Pave   NaN       IR1
#
#   Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 0          Lvl    AllPub     Corner  ...         0     NaN    NaN
# 1          Lvl    AllPub     Inside  ...         0     NaN  MnPrv
# 2          Lvl    AllPub     Corner  ...         0     NaN    NaN
# 3          Lvl    AllPub     Corner  ...         0     NaN    NaN
# 4          Lvl    AllPub     Inside  ...         0     NaN  MnPrv
#
#   Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  SalePrice
# ...

# %%
houseprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MS SubClass      2930 non-null   int64
#  1   MS Zoning        2930 non-null   object
#  2   Lot Frontage     2440 non-null   float64
#  3   Lot Area         2930 non-null   int64
#  4   Street           2930 non-null   object
#  5   Alley            198 non-null    object
#  6   Lot Shape        2930 non-null   object
#  7   Land Contour     2930 non-null   object
#  8   Utilities        2930 non-null   object
#  9   Lot Config       2930 non-null   object
#  10  Land Slope       2930 non-null   object
#  11  Neighborhood     2930 non-null   object
#  12  Condition 1      2930 non-null   object
#  13  Condition 2      2930 non-null   object
#  14  Bldg Type        2930 non-null   object
#  15  House Style      2930 non-null   object
# ...

# %%
print(f"rows: {houseprice.shape[0]}")
print(f"columns: {houseprice.shape[1]}")
# Out:
# rows: 2930
# columns: 80

# %%
#check categories with missing values
missing_values = houseprice.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Lot Frontage       490
# Alley             2732
# Mas Vnr Type      1775
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2917
# Fence             2358
# Misc Feature      2824
# dtype: int64

# %%
#impute missing values in numeric categories with the median
numeric_columns = houseprice.select_dtypes(include='number').columns
from sklearn.impute import SimpleImputer
imputerNum = SimpleImputer(strategy="median")
houseprice[numeric_columns] = imputerNum.fit_transform(houseprice[numeric_columns])

# %%
#impute missing values in categorical categories as 'unknown'
categorical_columns = houseprice.select_dtypes(include='object').columns
imputerCat = SimpleImputer(strategy='constant', fill_value='unknown')
houseprice[categorical_columns] = imputerCat.fit_transform(houseprice[categorical_columns])

# %%
#check missing values again to see there are none! yippieeee
missing_values = houseprice.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Series([], dtype: int64)

# %%
#print catergories and their specific values and count
categorical_columns = houseprice.select_dtypes(include='object').columns
for column in categorical_columns:
    print(houseprice[column].value_counts())
    print()
# Out:
# MS Zoning
# RL         2273
# RM          462
# FV          139
# RH           27
# C (all)      25
# I (all)       2
# A (agr)       2
# Name: count, dtype: int64
#
# Street
# Pave    2918
# Grvl      12
# Name: count, dtype: int64
#
# Alley
# unknown    2732
# Grvl        120
# Pave         78
# Name: count, dtype: int64
#
# Lot Shape
# Reg    1859
# IR1     979
# IR2      76
# IR3      16
# Name: count, dtype: int64
#
# Land Contour
# Lvl    2633
# HLS     120
# Bnk     117
# Low      60
# Name: count, dtype: int64
#
# Utilities
# AllPub    2927
# NoSewr       2
# NoSeWa       1
# Name: count, dtype: int64
#
# Lot Config
# Inside     2140
# Corner      511
# CulDSac     180
# FR2          85
# FR3          14
# Name: count, dtype: int64
#
# Land Slope
# Gtl    2789
# Mod     125
# Sev      16
# Name: count, dtype: int64
#
# Neighborhood
# NAmes      443
# CollgCr    267
# OldTown    239
# Edwards    194
# Somerst    182
# NridgHt    166
# Gilbert    165
# Sawyer     151
# ...

# %%
#houseprice = houseprice.drop("Street", axis=1).drop("Alley", axis=1).drop("Utilities", axis=1).drop("Roof Matl", axis=1).drop("Heating", axis=1).drop("Central Air", axis=1).drop("Electrical", axis=1).drop("Functional", axis=1).drop("Paved Drive", axis=1).drop("Misc Feature", axis=1)

# %% [markdown]
# ExterCond, BsmtCond,
